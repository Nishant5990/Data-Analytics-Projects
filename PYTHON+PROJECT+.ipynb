# %% [markdown]
# # 1 . Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("D:\\Downloads\\youtube_dislike_dataset.csv")
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
df.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
df.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# # 2 .Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %% [markdown]
# # comments

# %%
The dataset info consists of 37,422 rows and 12 columns.
Among these columns, 'view_count,' 'likes,' 'dislikes,' and 'comment_count' hold integer data types, 
while the remaining columns contain string data.

# %% [markdown]
# # 3 .Check for the Percentage of the missing values and drop or impute them.

# %%
df.isnull().sum()/df.shape[0]
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.004222
# dtype: float64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %%
df1=df.copy()

# %%
df1.to_csv('deploy.csv')

# %%
df1['comments'].fillna("Not known",inplace=True)

# %%
df1.to_csv('deploy.csv')

# %% [markdown]
# # Comments

# %%
By examining the dataframe's information, it becomes evident that the 'comments' column contains NaN values,
while all other columns are devoid of such missing values.

# %% [markdown]
# # 4. .Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
df.select_dtypes(include=['int64']).describe()
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %% [markdown]
# # Comments

# %%
1.The 'view_count' column ranges from a minimum of 20,368 to a maximum of 1,322,79e+09.
2.The average number of 'likes' received is approximately 166,814.
3.The total count of 'Dislikes' recorded amounts to 37,422e+04.

# %%
df2=pd.read_csv('deploy.csv')

# %%
 df2.select_dtypes(include=['object']).describe()
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37422  37422                     37422                37422
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description   comments
# count                 37422  37422       37422      37422
# unique                36772  28799       35630      37265
# top     2020-10-16 04:00:10                     Not known
# freq                      6   3817         589        158

# %% [markdown]
# # Comments

# %%
1 .The overall count across all columns sums up to 37,422.
2 .The 'channel_id' that appears most frequently is 'UCNAf1k0yIjyGu3k9BwAg3lg'.
3 .There are a total of 10,880 distinct 'channel_title' values found uniquely.

# %% [markdown]
# # 5.Convert datatype of column published_at from object to pandas datetime.

# %%
df2['published_at']=pd.DataFrame(pd.to_datetime(df2['published_at']))
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
df2.iloc[:,1:]
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %% [markdown]
# # Comments

# %%
In the final dataframe, the data type of the published_at column has been transformed from object to the 
Pandas datetime format.

# %% [markdown]
# # 6.Create a new column as 'published_month' using the column published_at (display the months only)

# %%
df2['published_month']=pd.DataFrame(df2['published_at'].dt.strftime('%m'))

# %%
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
df2.iloc[:,1:]
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# # Comments

# %%
The Datetime.strftime() method was employed to extract the month from the datetime data.

# %%
df2.to_csv('q6.csv')

# %% [markdown]
# # 7.Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb' and so on.....

# %%
df3=pd.read_csv('q6.csv')

# %%
{1:'Jan',2:'Feb',3:'Mar',4:'Apirl',5:'May',6:'Jun',7:'July',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'}
# Out:
# {1: 'Jan',
#  2: 'Feb',
#  3: 'Mar',
#  4: 'Apirl',
#  5: 'May',
#  6: 'Jun',
#  7: 'July',
#  8: 'Aug',
#  9: 'Sep',
#  10: 'Oct',
#  11: 'Nov',
#  12: 'Dec'}

# %%
df4=df3.replace({'published_month':{1:'Jan',2:'Feb',3:'Mar',4:'Apirl',5:'May',6:'Jun',7:'July',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'}})

# %%
df4
# Out:
#        Unnamed: 0.1  Unnamed: 0     video_id  \
# 0                 0           0  --0bCF-iK2E
# 1                 1           1  --14w5SOEUs
# 2                 2           2  --40TEbZ9Is
# 3                 3           3  --4tfbSyYDE
# 4                 4           4  --DKkzWVh-E
# ...             ...         ...          ...
# 37417         37417       37417  zzd4ydafGR0
# 37418         37418       37418  zziBybeSAtw
# 37419         37419       37419  zzk09ESX7e0
# 37420         37420       37420  zzmQEb0Em5I
# 37421         37421       37421  zzxPZwaA-8w
#
#                                                    title  \
# 0                   Jadon Sancho  Magical Skills & Goals
# 1                     Migos - Avalanche (Official Video)
# 2             Supporting Actress in a Comedy: 73rd Emmys
# 3                JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4                           Why Retaining Walls Collapse
# ...                                                  ...
# ...

# %%
df5=df4.iloc[:,2:]

# %%
df5
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %% [markdown]
# # Comments

# %%
In the final dataframe, the numbers in the 'published_month' column have been substituted with the corresponding names of the months.
For example, 1 has been replaced with 'Jan', 2 with 'Feb', and so forth

# %%
df5.to_csv("q8.csv")

# %% [markdown]
# # 8.Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
pd.DataFrame(df5.groupby(by=['published_month']).count()['video_id']).sort_values(by=['video_id'],ascending=False)
# Out:
#                  video_id
# published_month
# Oct                  4991
# Sep                  4880
# Nov                  4851
# Aug                  4262
# Dec                  3072
# July                 2340
# Jun                  2316
# Mar                  2258
# Feb                  2137
# Apirl                2126
# Jan                  2108
# May                  2081

# %% [markdown]
# # Comments

# %%
CHECKING THE PUBLISHED MONTH ORDER

# %% [markdown]
# # 9.Find the count of unique video_id, channel_id and channel_title.

# %%
df6=pd.read_csv('q8.csv').iloc[:,1:]
df6
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
len(df6['video_id'].unique())   # count of unique video_id
# Out:
# 37422

# %%
len(df6['channel_id'].unique())  #count of unique channel_id
# Out:
# 10961

# %%
len(df6['channel_title'].unique())   # count of unique channel
# Out:
# 10883

# %% [markdown]
# # 10.Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

# %%
df6.groupby(by=['channel_title']).agg({'video_id':'count'}).sort_values(by=['video_id'],ascending=False).head(10)
# Out:
#                      video_id
# channel_title
# Sky Sports Football       533
# The United Stand          301
# BT Sport                  246
# NBA                       209
# NFL                       162
# WWE                       122
# SSSniperWolf               99
# SSundee                    98
# FORMULA 1                  87
# NHL                        86

# %%
df6.groupby(by=['channel_title']).agg({'video_id':'count'}).sort_values(by=['video_id'],ascending=False).tail(10)
# Out:
#                 video_id
# channel_title
# Karchez                1
# Karate Combat          1
# Kaptain Kuba           1
# Kanye West             1
# Kannur kitchen         1
# Kannada Cinema         1
# KanalD                 1
# Kanak News             1
# Kamille Ramos          1
# zoom                   1

# %% [markdown]
# # 11.Find the title of the video which has the maximum number of likes and the           title of the video having minimum likes and write your inferences.

# %%
df6[['title','likes']]
# Out:
#                                                    title    likes
# 0                   Jadon Sancho  Magical Skills & Goals    19515
# 1                     Migos - Avalanche (Official Video)   359277
# 2             Supporting Actress in a Comedy: 73rd Emmys    11212
# 3                JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO    39131
# 4                           Why Retaining Walls Collapse    32887
# ...                                                  ...      ...
# 37417  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...  2180780
# 37418  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...    20759
# 37419                 [MV]  (MAMAMOO) - Where Are We Now   720854
# 37420              FELLIPE ESCUDERO- Master Podcast  #12    19198
# 37421  Gareth Bale brace secures dramatic comeback on...    34063
#
# [37422 rows x 2 columns]

# %%
df6[df6['likes']==df6['likes'].max()]['title']
# Out:
# 26143    BTS () 'Dynamite' Official MV
# Name: title, dtype: object

# %%
df6[df6['likes']==df6['likes'].min()]['title']
# Out:
# 18654    Kim Kardashian's Must-See Moments on "Saturday...
# Name: title, dtype: object

# %% [markdown]
# # Comments

# %%
The song 'Dynamite' by BTS received a significant number of likes, indicating its popularity, whereas 
'Must-see Moments on Saturday' by Kim Kardashian garnered only a limited number of likes.
This discrepancy underscores the substantial disparity in likes between the two, with 'Dynamite' far outpacing 
'Must-see Moments on Saturday'.

# %% [markdown]
# # 12.Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
df6[df6['dislikes']==df6['dislikes'].max()]['title']
# Out:
# 13591    Cuties | Official Trailer | Netflix
# Name: title, dtype: object

# %%
df6[df6['likes']==df6['likes'].min()]['title']
# Out:
# 18654    Kim Kardashian's Must-See Moments on "Saturday...
# Name: title, dtype: object

# %% [markdown]
# # Comments

# %%
The video 'Cuties' stands out as the most disliked, while Kim Kardashian's
 "Must-See Moments on Saturday" video has attracted comparably minimal dislikes.

# %% [markdown]
# # 13.Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
pd.DataFrame(df6[['dislikes','view_count']]).plot(x='view_count',y='dislikes',kind='scatter')
# Out:
# <Axes: xlabel='view_count', ylabel='dislikes'>

# %%
df6['dislikes'].corr(df6['view_count'])
# Out:
# 0.6844687753905543

# %% [markdown]
# # Comments

# %%
Indeed, the visualization illustrates a discernible pattern of relative uniformity. 
This suggests a proportional relationship between 'dislikes' and 'view_counts' up to a certain threshold. 
The correlation coefficient of 68% further supports this observation, signifying a substantial linkage between the two factors.
This robust correlation substantiates the premise that the number of views has a discernible impact on the quantity of dislikes a video receives

# %% [markdown]
# # 14.Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

# %%
df6[df6['published_month']=='Jan']
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title         published_at  \
# ...

# %%
df6[df6['published_month']=='Jan']['video_id'].count()
# Out:
# 2108

# %% [markdown]
# # Comments

# %%
All the information about the videos that were published in January.
