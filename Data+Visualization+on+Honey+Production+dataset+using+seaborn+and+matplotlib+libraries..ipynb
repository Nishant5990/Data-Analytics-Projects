# %% [markdown]
# ### Data Visualization on Honey Production dataset using seaborn and matplotlib libraries.
# ### Domain: Food and agriculture
# ### Context:
# In 2006, a global concern was raised over the rapid decline in the honeybee population, an integral component
# to American honey agriculture. Large numbers of hives were lost to “Colony-Collapse-Disorder”, a
# phenomenon of disappearing “worker-bees” causing the remaining “hive-colony” to collapse. Speculation
# around the cause of this disorder points to hive-diseases and pesticides harming the pollinators, though no
# overall consensus has been reached. Twelve years later, some industries are observing recovery but the
# American honey industry is still largely struggling. The U.S. used to locally produce over half the honey it
# consumes per year. Now, honey mostly comes from overseas, with 350 of the 400 million pounds of honey
# consumed every year originating from imports. This dataset provides insight into honey production supply and
# demand in America by state from 1998 to 2012.
# ### Objective:
# The Goal is to use Python visualization libraries such as seaborn and matplotlib to investigate the data and get
# some useful conclusions.
# ### Attribute Information:
# #### Attribute Description
# - **numcol :** Number of honey producing colonies.
# - **yield percol :** Honey yield per colony. (Unit is pounds)
# - **total prod :** Total production (numcol x yieldpercol). (Unit is pounds)
# - **price per lb :** Refers to average price per pound based on expanded sales. Unit is dollars.
# - **prodvalue :** Value of production (total prod x priceperlb). Unit is dollars.
# - **Stocks :** Refers to stocks held by producers. Unit is pounds
# - **Year :** Calendar year.
# - **State :** Different states' names.

# %% [markdown]
# <font size=3> Q1) Import required libraries and read the dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('honeyproduction1998-2016.csv')         # reading the dataset from csv

# %% [markdown]
# <font size=3> Q2) Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
df.head()    # display first 5 rows
# Out:
#         state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0     Alabama   16000.0           71   1136000.0    159000.0        0.72
# 1     Arizona   55000.0           60   3300000.0   1485000.0        0.64
# 2    Arkansas   53000.0           65   3445000.0   1688000.0        0.59
# 3  California  450000.0           83  37350000.0  12326000.0        0.62
# 4    Colorado   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
df.tail()         # display last 5 rows
# Out:
#              state   numcol  yieldpercol  totalprod     stocks  priceperlb  \
# 780       Virginia   5000.0           38   190000.0    30000.0        5.85
# 781     Washington  84000.0           35  2940000.0   412000.0        1.99
# 782  West Virginia   5000.0           32   160000.0    43000.0        3.92
# 783      Wisconsin  54000.0           62  3348000.0  1205000.0        2.67
# 784        Wyoming  40000.0           68  2720000.0   190000.0        1.78
#
#      prodvalue  year
# 780  1112000.0  2016
# 781  5851000.0  2016
# 782   627000.0  2016
# 783  8939000.0  2016
# 784  4842000.0  2016

# %%
df.shape
# Out:
# (785, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785 entries, 0 to 784
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        785 non-null    object
#  1   numcol       785 non-null    float64
#  2   yieldpercol  785 non-null    int64
#  3   totalprod    785 non-null    float64
#  4   stocks       785 non-null    float64
#  5   priceperlb   785 non-null    float64
#  6   prodvalue    785 non-null    float64
#  7   year         785 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 49.2+ KB

# %%
df.describe()
# Out:
#               numcol  yieldpercol     totalprod        stocks  priceperlb  \
# count     785.000000   785.000000  7.850000e+02  7.850000e+02  785.000000
# mean    61686.624204    60.578344  4.140957e+06  1.257629e+06    1.695159
# std     92748.940458    19.427831  6.884594e+06  2.211794e+06    0.930623
# min      2000.000000    19.000000  8.400000e+04  8.000000e+03    0.490000
# 25%      9000.000000    46.000000  4.700000e+05  1.190000e+05    1.050000
# 50%     26000.000000    58.000000  1.500000e+06  3.910000e+05    1.480000
# 75%     65000.000000    72.000000  4.096000e+06  1.380000e+06    2.040000
# max    510000.000000   136.000000  4.641000e+07  1.380000e+07    7.090000
#
#           prodvalue         year
# count  7.850000e+02   785.000000
# mean   5.489739e+06  2006.817834
# std    9.425394e+06     5.491523
# min    1.620000e+05  1998.000000
# 25%    9.010000e+05  2002.000000
# 50%    2.112000e+06  2007.000000
# 75%    5.559000e+06  2012.000000
# ...

# %%
df.describe(include = 'object').T
# Out:
#       count unique      top freq
# state   785     44  Alabama   19

# %% [markdown]
# Inferences
#
# 1. The dataset has 785 rows and 8 columns.
# 2. There are 8 columns in which 5 are float, 2 int and 1 object data type.
# 3. On average ~4 millions of honey produced in an american city.
# 4. On average ~5 million price worth of honey produced in each american city.

# %% [markdown]
# <font size=3> Q3) Display the percentage distribution of the data in each year using the pie chart.

# %%
df['year'].value_counts().plot(kind = 'pie', autopct = '%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# <font size=3> Q4) Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
sns.displot(data = df, x = 'priceperlb')

# %% [markdown]
# 1. From above plot, we can see there is right skew in the dataset.
# 2. Majority data points are concentrated between 0 to 3 priceperlb.

# %% [markdown]
# <font size=3> Q5) Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and
# write your findings.

# %%
sns.scatterplot(data = df, x = 'numcol', y = 'prodvalue')
# Out:
# <Axes: xlabel='numcol', ylabel='prodvalue'>

# %% [markdown]
# 1. From above plot, its clear that there is a linear relationship between numcol and prodvalue.
# 2. Between 0 to 2 lakh number of colony, there is strong relationship between the numcol and prodvalue.
# 3. After 2 lakh number of colony, the relationship between the numcol and prodvalue is getting weaker.

# %% [markdown]
# <font size=3> Q6) Plot and understand the relationship between categorical variable 'year' and a numerical variable
# 'prodvalue' through boxplot, and write your findings.

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(data = df, x = 'year', y = 'prodvalue')
plt.show()

# %% [markdown]
# 1. From the year 1998 to 2001, production value of honey is very less.
# 2. From the year 2002 to 2004, production value of honey was good compare to last 4 years.
# 3. form the year 2013 to 2016, production value of honey got better than last 10 years.

# %% [markdown]
# <font size=3> Q7) Visualize and understand the relationship between the multiple pairs of variables throughout different years
# using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year').

# %%
df_plot = pd.DataFrame(df, columns = ['numcol', 'yieldpercol', 'totalprod','prodvalue', 'year'])

# %%
sns.pairplot(data = df_plot, diag_kind = 'kde')

# %% [markdown]
# 1. There is a linear relationship between numcol and totalprod.with increase in number of colony, the production of honey
#    also increases.
# 2. Between numcol and prodvalue, there is a linear relationship.
# 3. Between numcol and yeildpercol, there is no linear relationship.but in the range of 0 to 2 lakh number of colony, the honey      produced range between 0 to 140 pounds.
# 4. There is linear relationship between totalprod and prodvalue.
# 5. Almost every year the production value is constant.

# %% [markdown]
# <font size=3> Q8) Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol',
# 'total prod', 'stocks', 'price per lb', 'prodvalue').

# %%
df_plot1 = pd.DataFrame(df, columns = ['numcol', 'yieldpercol', 'totalprod','stocks', 'priceperlb', 'prodvalue'])

# %%
ax = df_plot1.select_dtypes(include = 'number').corr()
sns.heatmap(ax, annot= True, cmap = 'plasma')
# Out:
# <Axes: >

# %% [markdown]
# 1. Positively Correlated pairs
#
#     * numcol - totalprod --> 0.95
#     * numcol - prodvalue --> 0.9
#     * totalprod - prodvalue --> 0.9
#     * totalprod - stocks --> 0.88
#     * numcol - stocks --> 0.82
#
# 2. Negatively Correlated pairs
#
#     * yieldpercol - priceperlb --> -0.36
#     * stocks - priceperlb --> -0.28
#     * totalprod - priceperlb --> -0.24
#     * numcol - priceperlb --> -0.21
#     * priceperlb - prodvalue --> -0.062
#
# 3. With increase in number of colony('numcol'), total production of honey also increases.
# 4. As increase in honey produce per colony (yeildpercol), the price (priceperlb) of honey decreases.
# 5. As the total production of honey increases, then the honey price get decreases.
